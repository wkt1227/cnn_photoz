# %%
from astropy.table import Table
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
table = Table.read('../data/external/COSMOS2015_Laigle+_v1.1.fits.gz')
# Out:
# WARNING: UnitsWarning: 'erg/cm2/s' contains multiple slashes, which is discouraged by the FITS standard [astropy.units.format.generic]

# %%
table2 = table[:]['ALPHA_J2000', 'DELTA_J2000', 'FLAG_PETER', 'PHOTOZ', 'TYPE', 'ZPDF', 'ZPDF_L68', 'ZPDF_H68', 'ZMINCHI2', 'CHI2_BEST', 'ZP_2', 'CHI2_2', 'NBFILT', 'ZQ', 'CHIQ', 'MODQ', 'MODS', 'CHIS', 'MODEL', 'AGE', 'EXTINCTION', 'MNUV', 'MU', 'MB', 'MV', 'MR', 'MI', 'MZ', 'MY', 'MJ', 'MH', 'MK', 'MNUV_MR', 'CLASS', 'MASS_MED', 'MASS_MED_MIN68', 'MASS_MED_MAX68', 'MASS_BEST', 'L_NU', 'L_R', 'L_K']

# %%
table2
# Out:
# <Table length=1182108>
#    ALPHA_J2000        DELTA_J2000     ...       L_R              L_K
#        deg                deg         ...
#      float64            float64       ...     float64          float64
# ------------------ ------------------ ... ---------------- ---------------
# 149.68318763276815 1.4354018133896047 ... 29.2319162117389 28.926819076952
#  149.6866381780836 1.4354525227506005 ... 29.7166262117389 29.819099076952
# 149.67109752619135 1.4354506867590184 ... 30.2501262117389 30.420649076952
# 149.69751106098735 1.4354887680463875 ... 28.3877662117389 28.150769076952
#  149.6805331339998 1.4354870618513438 ... 28.2301762117389 28.444279076952
#  149.6946928828636 1.4354795137759895 ... 28.9097962117389 28.848299076952
#  149.6655271567776  1.435461597929882 ... 30.1457262117389 30.435759076952
# 149.72351594321586  1.435540006600698 ... 28.7505762117389 28.865869076952
#  149.7066535453756 1.4355378982060971 ... 28.7254262117389 28.895919076952
# ...

# %%
df = table2.to_pandas()
df
# Out:
#          ALPHA_J2000  DELTA_J2000  FLAG_PETER     PHOTOZ  TYPE     ZPDF  \
# 0         149.683188     1.435402           8 -99.900002     0   2.2067
# 1         149.686638     1.435453           8 -99.900002     0   2.8249
# 2         149.671098     1.435451           8 -99.900002     0   3.7699
# 3         149.697511     1.435489           8 -99.900002     0   3.3574
# 4         149.680533     1.435487           8 -99.900002     0   3.3342
# ...              ...          ...         ...        ...   ...      ...
# 1182103   151.016122     3.039070           0 -99.900002     0 -99.0000
# 1182104   151.026803     3.044393           0 -99.900002     0 -99.0000
# 1182105   150.755096     3.044820           0 -99.900002     0   4.1190
# 1182106   151.037485     3.049715           0 -99.900002     0 -99.0000
# 1182107   151.048167     3.055007           4 -99.900002     0 -99.0000
#
#          ZPDF_L68  ZPDF_H68  ZMINCHI2     CHI2_BEST  ...         MK  \
# ...

# %%
# 銀河のみを抽出
df2 = df[(df['PHOTOZ'] == df['ZPDF'])]
df2
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df3 = df2[(df2['TYPE'] == 0)]
df3
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
# 0 < z < 9
df4 = df3[(df3['ZPDF'] > 0) & (df3['ZPDF'] < 9)]
df4
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
# ZP_2 < 0
df5 = df4[df4['ZP_2'] < 0]
df5
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df6 = df5[df5['MASS_MED'] > 7.5]
df6
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df7 = df6[(df6['CHI2_BEST']/df6['NBFILT']) < 5]
df7
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 216438   149.697606     1.616639           0  0.0386     0  0.0386    0.0201
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df8 = df7[df7['CHI2_BEST'] < df7['CHIS']]
df8
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219655   150.388349     1.614538           0  2.3343     0  2.3343    1.7689
# 219656   150.383607     1.614532           0  1.3916     0  1.3916    0.5868
# 219712   150.276828     1.614629           0  1.7792     0  1.7792    1.5887
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df9 = df8[(df8['ZPDF']-df8['ZPDF_L68']) < 0.05*(1+df8['ZPDF'])]
df9
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219855   150.151602     1.614697           0  2.4809     0  2.4809    2.3688
# 219928   150.255591     1.614860           0  1.2742     0  1.2742    1.2099
# 219964   150.405519     1.619062           0  0.0962     0  0.0962    0.0883
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df10 = df9[(df9['ZPDF_H68']-df9['ZPDF']) < 0.05*(1+df9['ZPDF'])]
df10
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219855   150.151602     1.614697           0  2.4809     0  2.4809    2.3688
# 219928   150.255591     1.614860           0  1.2742     0  1.2742    1.2099
# 219964   150.405519     1.619062           0  0.0962     0  0.0962    0.0883
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df10[df10['FLAG_PETER']==0]
# Out:
#         ALPHA_J2000  DELTA_J2000  FLAG_PETER  PHOTOZ  TYPE    ZPDF  ZPDF_L68  \
# 218603   149.749393     1.618068           0  0.3797     0  0.3797    0.3729
# 219019   150.125093     1.616900           0  0.1600     0  0.1600    0.1532
# 219855   150.151602     1.614697           0  2.4809     0  2.4809    2.3688
# 219928   150.255591     1.614860           0  1.2742     0  1.2742    1.2099
# 219964   150.405519     1.619062           0  0.0962     0  0.0962    0.0883
# ...             ...          ...         ...     ...   ...     ...       ...
# 994830   150.684320     2.812115           0  0.4794     0  0.4794    0.4719
# 994832   150.769114     2.813175           0  0.4095     0  0.4095    0.4027
# 995117   150.197234     2.813222           0  0.4300     0  0.4300    0.4232
# 995163   150.167301     2.812681           0  0.1799     0  0.1799    0.1730
# 995745   150.369545     2.813348           0  0.1884     0  0.1884    0.1815
#
# ...

# %%
df10.to_csv('../data/interim/COSMOS2015.csv')

# %%
df10 = pd.read_csv('../data/interim/COSMOS2015.csv')

# %%
z_list = df10['PHOTOZ'].to_numpy()

# %%
plt.hist(z_list, bins=600)
plt.show()

# %%
plt.hist(z_list, bins=600)
plt.ylim(0, 1000)
plt.show()
